# %%
from PIL import Image
from pylab import *
# %matplotlib inline

# %%
arr = array(Image.open("images/MARBLES.bmp"))

x = [125, 150, 243, 2]
y = [386, 10, 72, 411]

plot(x, y, "r*")

imshow(arr)

# %%
plot(x, y, "r")

imshow(arr)

# %%
plot(x, y, "c:")

imshow(arr)

# %%
title("I want my chicken-roll!!!111")

imshow(arr)

# %%
# Select 4 points by clicking

# %matplotlib tk
imshow(arr)

pts = ginput(4)

# %matplotlib inline

print("Selected", pts)
# Out:
# Selected [(398.25910596026483, 572.3681015452539), (394.5762509197937, 452.6753127299485), (408.61713576158934, 452.6753127299485), (408.61713576158934, 452.6753127299485)]
