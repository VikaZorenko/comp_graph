# %%
from PIL import Image
from pylab import *

# %%
def negative(img_arr):
    return 255 - img_arr

# %%
img = array(Image.open('images/minions.jpg'))
Image.fromarray(negative(img))
# Out:
# <PIL.Image.Image image mode=RGB size=300x168 at 0x7F5C933AAF50>

# %%
def clamp(img, start_end):
    start, end = start_end
    diff = end - start
    
    return np.asarray(diff / 255 * img + start).astype(np.uint8)

# %%
Image.fromarray(clamp(img, (100, 200)))
# Out:
# <PIL.Image.Image image mode=RGB size=300x168 at 0x7F5C931D2590>
